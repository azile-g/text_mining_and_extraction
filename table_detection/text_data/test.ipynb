# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#the usual suspects
import pandas as pd
import fitz

#ownself parser
from parser import doc_type_init as doc_type, text_table_parser as table_parser

# %%
skills_settings = doc_type(
    ["name", 
    "description", 
    "industry", 
    "category", 
    "type", 
    [6, "levels", "level", "description", "knowledge", "abilities"]
    ],
    "TSC Category", ["TSC", 2],
    ["TSC", 2], "TSC Description",
    "TSC Description", "TSC Proficiency Description",
    "TSC Proficiency Description", "Knowledge", 
    "Knowledge", "Abilities",
    "Abilities", "SkillsFuture Singapore and Institute of Banking and Finance"
    )
skills_template = doc_type.create_target_template(skills_settings)
print(skills_template)
# Out:
# {'target': {'name': [], 'description': [], 'industry': [], 'category': [], 'type': [], 'levels': [{'level': [], 'description': [], 'knowledge': [], 'abilities': []}, {'level': [], 'description': [], 'knowledge': [], 'abilities': []}, {'level': [], 'description': [], 'knowledge': [], 'abilities': []}, {'level': [], 'description': [], 'knowledge': [], 'abilities': []}, {'level': [], 'description': [], 'knowledge': [], 'abilities': []}, {'level': [], 'description': [], 'knowledge': [], 'abilities': []}]}, 'kwds': {'front': ['TSC Category', ['TSC', 2], 'TSC Description', 'TSC Proficiency Description', 'Knowledge', 'Abilities'], 'back': [['TSC', 2], 'TSC Description', 'TSC Proficiency Description', 'Knowledge', 'Abilities', 'SkillsFuture Singapore and Institute of Banking and Finance']}}

# %%
# Out:
# ('one', 'two')

# %%
skills_pdf = r"C:\Users\ELIZABETH CHENG\source\repos\text_mining\RLH_text_ext\testing\target_reader\Account Management_FIN_Customer_TSC_P.pdf"
doc = fitz.open(skills_pdf)
page = doc[1]
top_str = "Abilities"
bot_str = "SkillsFuture Singapore and Institute of Banking and Finance"
test_coords = table_parser.find_table(page, top_str, bot_str)
test_tbl, test_text = table_parser.parse_table(page, test_coords, merged_rows = True)
display(test_text)
# Out:
# [Rect(85.53648376464844, 752.6279907226562, 377.7763671875, 767.7969360351562)]
#              0           1           2           3              4  5  6  7
# 0    77.400002  752.627991  143.010727  767.796936  ©SkillsFuture  0  0  0
# 1   146.079849  752.627991  196.245621  767.796936      Singapore  0  0  1
# 2   199.138107  752.627991  217.519714  767.796936            and  0  0  2
# 3   220.588837  752.627991  259.118439  767.796936      Institute  0  0  3
# 4   262.187561  752.627991  271.284515  767.796936             of  0  0  4
# 5   274.441956  752.627991  314.042419  767.796936        Banking  0  0  5
# 6   317.133606  752.627991  335.515228  767.796936            and  0  0  6
# 7   338.584351  752.627991  377.776367  767.796936        Finance  0  0  7
# 8   566.929993  752.507996  592.741516  767.676941           Page  0  1  0
# 9   595.849976  752.563171  601.988220  767.765259              2  0  1  1
# ...

# %%
# Out:
# Rect(0.0, 199.16717529296875, 9999.0, 346.1971740722656)

# %%
tabula.environment_info()
# Out:
# Python version:
#     3.10.0 (tags/v3.10.0:b494f59, Oct  4 2021, 19:00:18) [MSC v.1929 64 bit (AMD64)]
# Java version:
#     java version "1.8.0_351"
# Java(TM) SE Runtime Environment (build 1.8.0_351-b10)
# Java HotSpot(TM) Client VM (build 25.351-b10, mixed mode)
# tabula-py version: 2.6.0
# platform: Windows-10-10.0.18363-SP0
# uname:
#     uname_result(system='Windows', node='DESKTOP-RICJU5M', release='10', version='10.0.18363', machine='AMD64')
# linux_distribution: ('', '', '')
# mac_ver: ('', ('', '', ''), '')

# %%
skills_pdf = r"C:\Users\ELIZABETH CHENG\source\repos\text_mining\RLH_text_ext\testing\target_reader\Account Management_FIN_Customer_TSC_P.pdf"
test_df = tabula.read_pdf(skills_pdf, pages = "all", lattice = True)
for i in range(len(test_df)):
    display(test_df[i])
# Out:
# Empty DataFrame
# Columns: [Account Management, ccount Management]
# Index: []
#                      Unnamed: 0  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5  TSC Proficiency\rDescription
# 6                   Description
# 7                           NaN
# 8                     Knowledge
#
#                                         TSC Category Unnamed: 1  \
# 0                                                NaN        NaN
# 1                                                TSC        NaN
# 2                                                NaN        NaN
# 3                                    TSC Description        NaN
# 4  f quality solutions and service to address cus...        NaN
# 5                                    TSC Proficiency    Level 1
# 6                                                NaN        NaN
# ...

# %%
test_path = r"C:\Users\ELIZABETH CHENG\source\repos\text_mining\RLH_text_ext\testing\target_reader\01 Process Technician.pdf"
dfs = tabula.read_pdf(test_path, pages = "all", lattice = True, pandas_options={'header': None})
# read_pdf returns list of DataFrames
print(len(dfs))
display(dfs[0])
# Out:
# 9
#                                                     0  \
# 0   SKILLS FRAMEWORK FOR FOOD MANUFACTURING\rSKILL...
# 1                                                 NaN
# 2                                               Track
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                            Job Role
# 8                               Job Role\rDescription
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                           Job Role
# 14                                                NaN
# 15                                        Description
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\ELIZABETH CHENG\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\ELIZABETH CHENG\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\ELIZABETH CHENG\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...
